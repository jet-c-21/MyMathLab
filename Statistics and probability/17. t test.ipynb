# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# import self-made module
import os, sys, pathlib
file_path = os.path.abspath('')
PROJECT_DIR = str(pathlib.Path(file_path).parent)
sys.path.append(PROJECT_DIR)
print(f"Added {PROJECT_DIR} to PATH")
from athena import *
from sympy.vector import CoordSys3D, gradient, curl, ParametricRegion, vector_integrate, scalar_potential
from sympy.integrals.manualintegrate import integral_steps

sp.init_printing()

# ult functions
def reset_symbols():
    global x, y, z, a, b, c, d, e, f, g, h, r, s, k, t, u, v, theta, lmda, rho, phi
    x, y, z = sp.symbols('x y z', real=True)
    a, b, c, d, e, f, g, h, r, s, k, t, u, v = sp.symbols('a b c d e f g h r s k t u v', real=True)
    theta = sp.Symbol('theta')
    lmda = sp.Symbol('lambda')
    rho = sp.Symbol('rho')
    phi = sp.Symbol('phi')
    

reset_symbols()

import statistics
import math
import numpy as np
import scipy
# Out:
# Added D:\Dev\Code\MyMathLab to PATH

# %%
get_t_star(0.99, 10-1)
# Out:
# 3.2498355440153697

# %%
get_t_star(0.9, 6)
# Out:
# 1.9431802803927822

# %%
get_t_star(0.95, 20-1)
# Out:
# 2.093024054408263

# %%
mean = 6.8
s_n = 5
std = 1.64
cl = 0.95

std_of_sdist = std / math.sqrt(s_n)

t_star = get_t_star(cl, s_n - 1)
t_star

moe = std_of_sdist * t_star
moe


print(f"{mean} ± {round(moe, 3)}")
(mean - moe, mean + moe)
# Out:
# 2.7764451051977987
# 2.036328957054177
# 6.8 ± 2.036
# (4.763671042945823, 8.836328957054176)

# %%
mean = 9.5
s_n = 6
std = 8.07
cl = 0.95

std_of_sdist = std / math.sqrt(s_n)

t_star = get_t_star(cl, s_n - 1)
t_star

moe = std_of_sdist * t_star
moe


print(f"{mean} ± {round(moe, 3)}")
(mean - moe, mean + moe)
# Out:
# 2.5705818366147395
# 8.468945617184078
# 9.5 ± 8.469
# (1.0310543828159222, 17.968945617184076)

# %%
get_smallest_sample_size_with_fixed_moe_and_cl_by_z_and_pstd(10, 0.9, 15)
# Out:
# 6.087472771714682

# %%
get_smallest_sample_size_with_fixed_moe_and_cl_by_z_and_pstd(5, 0.95, 12)
# Out:
# 22.12680280719816

# %%
get_smallest_sample_size_with_fixed_moe_and_cl_by_z_and_pstd(100, 0.99, 300)
# Out:
# 59.714069409190905

# %%
get_smallest_sample_size_with_fixed_moe_and_cl_by_z_and_pstd(10, 0.9, 15)
# Out:
# 6.087472771714682

# %%
get_t_star(0.95, 9)
# Out:
# 2.2621571627409915

# %%
s_n = 10
s_mean = 17.17
s_std = 2.98
cl = 0.95

get_confidence_interval_of_mean_by_t(s_n, s_mean, s_std, cl)
# Out:
# (15.038236420261336, 19.301763579738665)

# %%
sample = [1.5, 2.9, 0.9, 3.9, 3.2, 2.1, 1.9]
statistics.mean(sample)
# scipy.stats.tmean(sample)

statistics.stdev(sample)
scipy.stats.tstd(sample)
# scipy.stats.std(sample)
# Out:
# 2.342857142857143
# 2.342857142857143
# 1.042204622994197
# 1.042204622994197

# %%
sample = [1.5, 2.9, 0.9, 3.9, 3.2, 2.1, 1.9]
s_n = len(sample)
s_mean = statistics.mean(sample)
s_std = statistics.stdev(sample)
cl = 0.95

get_confidence_interval_of_mean_by_t(s_n, s_mean, s_std, cl)
# Out:
# (1.378978629330552, 3.306735656383734)
